# %%
import pandas as pd

# Load the data
df = pd.read_csv('../vn_index/hose_historical_data.csv')

# Remove duplicates
df.drop_duplicates(inplace=True)

# Remove the 'Change'column
df.drop(columns=['Change'], inplace=True)

# Remove rows with missing values
df.replace('---', pd.NA, inplace=True)  
df.dropna(inplace=True)

# Convert 'Date' to datetime type
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')

# %%
df
# Out:
#       Index       Date  VN-INDEX   Total Volume    Total Value  \
# 0         0 2025-04-03   1229.84  1,763,077,400  39,630.15 bil
# 1         1 2025-04-02   1317.83    849,307,834  19,296.71 bil
# 2         2 2025-04-01   1317.33    620,033,587  15,025.64 bil
# 3         3 2025-03-31   1306.86    867,812,434  21,205.64 bil
# 4         4 2025-03-28   1317.46    739,652,036  17,084.16 bil
# ...     ...        ...       ...            ...            ...
# 4542   4542 2007-01-08    825.11      8,911,220   1,088.81 bil
# 4543   4543 2007-01-05    818.51      8,119,454     972.26 bil
# 4544   4544 2007-01-04    788.82      5,998,810     652.08 bil
# 4545   4545 2007-01-03    757.71      4,485,494     400.70 bil
# 4546   4546 2007-01-02    741.27      3,825,510     370.82 bil
#
#      Total Foreigner Buy Volume Total Foreigner Buy Value  \
# 0                    65,698,308              2,039.66 bil
# 1                    66,044,032              1,957.07 bil
# 2                    52,789,640              1,876.93 bil
# 3                    53,798,688              1,684.46 bil
# 4                    62,460,716              1,650.07 bil
# ...                         ...                       ...
# 4542                    525,000                 49.90 bil
# 4543                    663,600                 66.71 bil
# 4544                    123,300                  6.17 bil
# 4545                      8,000                454.25 mil
# 4546                     24,600                  1.43 bil
#
#      Total Foreigner Sell Volume Total Foreigner Sell Value
# 0                    198,638,382               5,734.34 bil
# 1                     81,823,582               2,665.49 bil
# 2                     64,539,449               2,316.52 bil
# 3                     89,320,381               2,966.36 bil
# 4                     62,678,442               2,056.68 bil
# ...                          ...                        ...
# 4542                      10,300                   1.55 bil
# 4543                      10,800                 470.54 mil
# 4544                       8,000                   1.28 bil
# 4545                      22,000                   2.55 bil
# 4546                      20,000                   2.10 bil
#
# [4532 rows x 9 columns]

# %%
# Function to convert values to numeric, handling 'mil', 'bil', and commas
def convert_to_numeric(value):
    if isinstance(value, str):
        value = value.replace(',', '')  # Remove commas
        if ' bil' in value:  
            return float(value.replace(' bil', '')) * 1e9  # Convert 'bil' to numeric
        elif ' mil' in value:
            return float(value.replace(' mil', '')) * 1e6  # Convert 'mil' to numeric
    return float(value)  # Convert remaining values

# %%
# Apply the conversion to all relevant columns
columns_to_convert = [
    'Total Volume', 'Total Value', 'Total Foreigner Buy Volume', 
    'Total Foreigner Buy Value', 'Total Foreigner Sell Volume', 
    'Total Foreigner Sell Value'
]

for col in columns_to_convert:
    df[col] = df[col].apply(convert_to_numeric)

# %%
# Convert other columns to numerical types
df['VN-INDEX'] = df['VN-INDEX'].astype(float)
df.rename(columns={'VN-INDEX': 'VN_Index_Close'}, inplace=True)

df = df.sort_values('Date')

# Save the cleaned data to a new CSV file
df.to_csv('../ready_data/cleaned_hose_historical_data.csv', index=False)

print("Data preprocessing completed and saved to 'cleaned_hose_historical_data.csv'")
# Out:
# Data preprocessing completed and saved to 'cleaned_hose_historical_data.csv'
